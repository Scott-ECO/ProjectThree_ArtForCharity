# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
# Reading in the African Elephant csv file
African_Elephant = Path("../African_Elephant_Graph_Data.csv")
African_Elephant_df = pd.read_csv(African_Elephant,index_col="year",infer_datetime_format = True,parse_dates = True)
African_Elephant_df
# Out:
#             African Elephant Population
# year
# 2000-01-01                         4500
# 2001-01-01                         5800
# 2002-01-01                         5900
# 2003-01-01                         6100
# 2004-01-01                         6000
# 2005-01-01                         5700
# 2006-01-01                         4000
# 2007-01-01                         2100
# 2008-01-01                         1800
# 2009-01-01                         1500
# 2010-01-01                         1400
# 2011-01-01                         1400
# 2012-01-01                         1350
# 2013-01-01                         1300
# 2014-01-01                         1300
# 2015-01-01                         1300

# %%
African_Elephant_Facts = Path("../AfricanForestElephantFacts.csv")
African_Elephant_Facts_df = pd.read_csv(African_Elephant_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
African_Elephant_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                            Critically Endangered
# Current Population                                                              415,000
# Habitat                               Tropical and Subtropical Moist Broadleaf Fores...
# Cause of Status                       Habitat loss, fragmentation, deforestation, po...
# Climate change impacts                The impacts of war and over exploitation of na...
# Human-Wildlife conflict               As elephants loose their habitats, damage to f...
# Poaching and illegal wildlife trade:  Illegal demand for ivory and elephants are see...
# Organizations that help:              World Wildlife Fund, nternational Elephant Fou...
# What can humans do to help:                  A symbolic animal adoption. A NFT purchase
# ...

# %%
#Plotting the African Elephant data
African_Elephant_df.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Reading in the Giant Panda csv file
Giant_Panda = Path("../Giant_Panda_Data.csv")
Giant_Panda_df = pd.read_csv(Giant_Panda,index_col="year",infer_datetime_format = True,parse_dates = True)
Giant_Panda_df
# Out:
#             Giant Panda population
# year
# 2000-01-01                    1300
# 2001-01-01                    1350
# 2002-01-01                    1400
# 2003-01-01                    1450
# 2004-01-01                    1500
# 2005-01-01                    1525
# 2006-01-01                    1550
# 2007-01-01                    1600
# 2008-01-01                    1625
# 2009-01-01                    1650
# 2010-01-01                    1675
# 2011-01-01                    1675
# 2012-01-01                    1675
# 2013-01-01                    1675
# 2014-01-01                    1680
# 2015-01-01                    1680
# 2016-01-01                    1700
# 2017-01-01                    1725
# 2018-01-01                    1750
# 2019-01-01                    1780
# 2020-01-01                    1800

# %%
Giant_Panda_Facts = Path("../Giant PandaFacts.csv")
Giant_Panda_Facts_df = pd.read_csv(Giant_Panda_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Giant_Panda_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                                       Vulnerable
# Current Population                                                                1,864
# Habitat                               Temperment forests high in the mountains of So...
# Cause of Status                       Infastructure development and forest loss is i...
# Climate change impacts                                                          Minimal
# Human-Wildlife conflict               Hunting, poaching and accidental capture in sn...
# Poaching and illegal wildlife trade:           Poaching, hunting and accidental capture
# Organizations that help:              World Wildlife Fund, increasing Panda habitat ...
# What can humans do to help:                  A symbolic animal adoption. A NFT purchase
# ...

# %%
#Plotting Giant Panda data
Giant_Panda_df.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Reading in the Sea Turtle csv file
Sea_Turtle = Path("../Sea_Turtle_Nest_Data.csv")
Sea_Turtle_df = pd.read_csv(Sea_Turtle,index_col="year",infer_datetime_format = True,parse_dates = True)
Sea_Turtle_df
# Out:
#             Sea Turtle Nest Population
# year
# 2000-01-01                        2200
# 2001-01-01                         200
# 2002-01-01                        2300
# 2003-01-01                         750
# 2004-01-01                        1000
# 2005-01-01                        2600
# 2006-01-01                        1300
# 2007-01-01                        4000
# 2008-01-01                        2500
# 2009-01-01                        1025
# 2010-01-01                        4020
# 2011-01-01                        5800
# 2012-01-01                        2500
# 2013-01-01                       11900
# 2014-01-01                        1800
# 2015-01-01                       12500
# 2016-01-01                        1780
# 2017-01-01                       16000

# %%
Sea_Turtle_Facts = Path("../SeaTurtleFacts.csv")
Sea_Turtle_Facts_df = pd.read_csv(Sea_Turtle_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Sea_Turtle_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                                       Endangered
# Current Population                                                          6.5 million
# Habitat                                                          Open waters and coasts
# Cause of Status                        Poaching, habitat destruction and accidential...
# Climate change impacts                Altering sand temperatures effect the sex of h...
# Human-Wildlife conflict               Incidental capture by fishing gear, uncotrolle...
# Poaching and illegal wildlife trade:  Illegal harvesting of their eggs, meat, skin a...
# Organizations that help:              World Wildlife fund, they help by reducing tur...
# What can humans do to help:                              A financial gift. NFT purchase
# ...

# %%
#Plotting Seat Turtle data
Sea_Turtle_df.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Reading in the Javan Rhino csv file
Javan_Rhino = Path("../JavanRhinoPopulation.csv")
Javan_Rhino_df = pd.read_csv(Javan_Rhino,index_col="Year",infer_datetime_format = True,parse_dates = True)
Javan_Rhino_df
# Out:
#             Javan Rhino Population
# Year
# 2000-01-01                      44
# 2001-01-01                      43
# 2002-01-01                      42
# 2003-01-01                      41
# 2004-01-01                      10
# 2005-01-01                      40
# 2006-01-01                      39
# 2007-01-01                      40
# 2008-01-01                      41
# 2009-01-01                      40
# 2010-01-01                      40
# 2011-01-01                      43
# 2012-01-01                      47
# 2013-01-01                      53
# 2014-01-01                      56
# 2015-01-01                      60
# 2016-01-01                      62
# 2017-01-01                      64
# 2018-01-01                      65
# 2019-01-01                      68
# 2020-01-01                      73
# 2021-01-01                      74

# %%
Javan_Rhino_Facts = Path("../JavanRhinoFacts.csv")
Javan_Rhino_Facts_df = pd.read_csv(Javan_Rhino_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Javan_Rhino_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                            Critically Endangered
# Current Population                                                                   68
# Habitat                               Tropical and subtropical grasslands, savannas ...
# Cause of Status                       Natural catastrophes, habitat loss, diseases, ...
# Climate change impacts                               Effects of climate change: Minimal
# Human-Wildlife conflict               Habitat loss due to expanding human population...
# Poaching and illegal wildlife trade:  Growing consumer demand for rhino horn has dri...
# Organizations that help:              The African Wildlife Federation, World Wildlif...
# What can humans do to help:           Make a symbolic rhino adoption , Sign an onlin...
# ...

# %%
#Plotting Javan Rhino data
Javan_Rhino_df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Reading in the Mountain Gorilla csv file
Mountain_Gorilla = Path("../MountainGorillaPopulation.csv")
Mountain_Gorilla_df = pd.read_csv(Mountain_Gorilla,index_col="Year",infer_datetime_format = True,parse_dates = True)
Mountain_Gorilla_df
# Out:
#             Mountain Gorilla Population
# Year
# 1970-01-01                          270
# 1975-01-01                          260
# 1980-01-01                          230
# 1985-01-01                          280
# 1990-01-01                          305
# 1995-01-01                          320
# 2000-01-01                          360
# 2005-01-01                          400
# 2010-01-01                          470
# 2015-01-01                          580
# 2020-01-01                          650

# %%
Mountain_Gorilla_Facts = Path("../MountainGorillaFacts.csv")
Mountain_Gorilla_Facts_df = pd.read_csv(Mountain_Gorilla_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Mountain_Gorilla_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                                       Endangered
# Current Population                                                               > 1000
# Habitat                                                   Forests high in the mountains
# Cause of Status                             Habitat loss, disease, charcoal making, war
# Climate change impacts                                                          Minimal
# Human-Wildlife conflict               Land clearing for agriculture and livestock, w...
# Poaching and illegal wildlife trade:  Poaching and accidental capture from poachers ...
# Organizations that help:                                            World Wildlife Fund
# What can humans do to help:                    A symbolic animal adoption. NFT purchase
# ...

# %%
#Plotting Mountain Grilla data
Mountain_Gorilla_df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Reading in the Plains Bison csv file
Plains_Bison = Path("../PlainsBisonPopulation.csv")
Plains_Bison_df = pd.read_csv(Plains_Bison,index_col="Year",infer_datetime_format = True,parse_dates = True)
Plains_Bison_df
# Out:
#             Plains Bison Population
# Year
# 1890-01-01                      512
# 1900-01-01                      750
# 1910-01-01                     1200
# 1920-01-01                     2432
# 1930-01-01                     3856
# 1940-01-01                     4352
# 1950-01-01                     6541
# 1960-01-01                     9561
# 1970-01-01                    13587
# 1980-01-01                    18788
# 1990-01-01                    23578
# 2000-01-01                    27565
# 2010-01-01                    29853
# 2020-01-01                    31000

# %%
Plains_Bison_Facts = Path("../PlainsBisonFacts.csv")
Plains_Bison_Facts_df = pd.read_csv(Plains_Bison_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Plains_Bison_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                                  Near Threatened
# Current Population                                                               31,000
# Habitat                                                                 Open grasslands
# Cause of Status                       Habitat loss, hunting, genetic modification to...
# Climate change impacts                               Effects of climate change: Minimal
# Human-Wildlife conflict                                       Hunting, domestification,
# Poaching and illegal wildlife trade:                                    Over harvesting
# Organizations that help:                                            World Wildlife Fund
# What can humans do to help:           A financial gift, corporate sponsorship, NFT p...
# ...

# %%
#Plotting Plains Bison data
Plains_Bison_df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Reading in the Polar Bear data
Polar_Bear = Path("../PolarBearPopulation.csv")
Polar_Bear_df = pd.read_csv(Polar_Bear,index_col="Year",infer_datetime_format = True,parse_dates = True)
Polar_Bear_df
# Out:
#             Polar Bear Population
# Year
# 2000-01-01                  24000
# 2001-01-01                  23000
# 2002-01-01                  23000
# 2003-01-01                  23000
# 2004-01-01                  23000
# 2005-01-01                  23000
# 2006-01-01                  23000
# 2007-01-01                  23000
# 2008-01-01                  23000
# 2009-01-01                  23000
# 2010-01-01                  23000
# 2011-01-01                  23000
# 2012-01-01                  23000
# 2013-01-01                  23000
# 2014-01-01                  24000
# 2015-01-01                  26450
# 2016-01-01                  28550
# 2017-01-01                  30254
# 2018-01-01                  32485
# 2019-01-01                  34885
# 2020-01-01                  36000

# %%
Polar_Bear_Facts = Path("../PolarBearFacts.csv")
Polar_Bear_Facts_df = pd.read_csv(Polar_Bear_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Polar_Bear_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                               vulnerable species
# Current Population                                                               26,000
# Habitat                                                                   Artic sea ice
# Cause of Status                       Climate warming, polution, disease, overharves...
# Climate change impacts                                                     Sea ice loss
# Human-Wildlife conflict               Commercial activity, conflicts and encounters,...
# Poaching and illegal wildlife trade:                                     Overharvesting
# Organizations that help:              Polar bears international, World Wildlife Fund...
# What can humans do to help:           A financial gift, corporate sponsorship, fundr...
# ...

# %%
#Plotting Polar Bear data
Polar_Bear_df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Reading in the Tiger Population data
Tiger_Data = Path("../TigerPopulation.csv")
Tiger_Data_df = pd.read_csv(Tiger_Data,index_col="Year",infer_datetime_format = True,parse_dates = True)
Tiger_Data_df
# Out:
#             Tiger Population
# Year
# 2000-01-01             40000
# 2001-01-01             37555
# 2002-01-01             32579
# 2003-01-01             28589
# 2004-01-01             22665
# 2005-01-01             15556
# 2006-01-01             11556
# 2007-01-01              8985
# 2008-01-01              6564
# 2009-01-01              4800
# 2010-01-01              3200
# 2011-01-01              3290
# 2012-01-01              3586
# 2013-01-01              3784
# 2014-01-01              4285
# 2015-01-01              4325
# 2016-01-01              4562
# 2017-01-01              4632
# 2018-01-01              4798
# 2019-01-01              4866
# 2020-01-01              4950
# 2021-01-01              5002

# %%
Tiger_Data_Facts = Path("../TigerFacts.csv")
Tiger_Data_Facts_df = pd.read_csv(Tiger_Data_Facts,index_col="Category",infer_datetime_format = True,parse_dates = True)
Tiger_Data_Facts_df
# Out:
#                                                                                    Fact
# Category
# Status                                                                       Endangered
# Current Population                                                                3,900
# Habitat                                              Forests and grasslands across Asia
# Cause of Status                       Over 95% of their habitat has been lost to cle...
# Climate change impacts                Effects of climate change: Rising sea levels a...
# Human-Wildlife conflict               As forests shrink and prey becomes scarce, tig...
# Poaching and illegal wildlife trade:   their bones, and other body parts are used fo...
# Organizations that help:               World Wildlife Fund. They help by preserving ...
# What can humans do to help:            Make a gift to WWF's global conservation efforts
# ...

# %%
#Plotting Tiger data
Tiger_Data_df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>
